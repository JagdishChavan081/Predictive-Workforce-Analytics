# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib widget
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# **pd.read_csv()**: read_csv() function in Pandas is used to read data from a CSV (Comma Separated Values) file and load it into a DataFrame.
#
# - It is one of the most commonly used functions in Pandas for importing data from external sources.
# - **pd** is the alias for the Pandas library, which was imported earlier using import pandas as pd.
#   .read_csv() is a Pandas function specifically designed to read CSV files.
# - **filename.csv** is the path to the CSV file you want to read. Replace 'filename.csv' with the actual file path or URL of your CSV file.
#
# Additional parameters can be passed to .read_csv() to customize how the data is read. Some common parameters include:
#
# - **sep**: Specifies the delimiter used in the CSV file. The default is ,.
# - **header**: Specifies which row in the CSV file contains the column names. The default is 0 (the first row).
# - **index_col**: Specifies which column in the CSV file should be used as the index of the DataFrame.
# - **dtype**: Specifies the data types of columns in the DataFrame.
# - **na_values**: Specifies additional strings to recognize as missing values.

# %%
#import dataset
data = pd.read_csv('F:/Predictive-Workforce-Analytics/01_data/Human_Resources.csv')

# %%
#check Data
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# - **.head()**: method in Pandas is used to display the first few rows of a DataFrame.
# - It is particularly useful when you want to quickly inspect the structure and contents of a DataFrame without displaying the entire dataset.
#
# - By default, .head() displays the first 5 rows of the DataFrame. However, you can specify the number of rows you want to display by passing an integer argument to the method. For example, df.head(10) would display the first 10 rows of the DataFrame.

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# **.tail()**: method in Pandas is the counterpart to the .head() method. While .head() displays the first few rows of a DataFrame,
#
# - .tail() displays the last few rows.
# - By default, .tail() displays the last 5 rows of the DataFrame.
# - Similar to .head(), you can specify the number of rows you want to display by passing an integer argument to the method. For example, df.tail(10) would display the last 10 rows of the DataFrame.

# %%
data.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %% [markdown]
# **.info()**: .info() method is used to provide a concise summary of a DataFrame.
#
# - When you call .info() on a DataFrame, it returns information about the DataFrame, including the data types of each column, the number of non-null values, and the memory usage.
#
# **key information provided by .info():**
#
# - **Data Types**: The method displays the data types of each column in the DataFrame. This is useful for understanding the nature of the data, whether it's numerical (int, float), categorical (object), or datetime.
#
# - **Non-Null Counts**: For each column, .info() shows the number of non-null (non-missing) values. This information helps identify columns with missing data.
#
# - **Memory Usage**: The method provides an estimate of the memory usage of the DataFrame. This can be useful for assessing the memory footprint of your DataFrame, especially when working with large datasets.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# **Findings**
#
# - The DataFrame contains 1470 entries.
# - There are 35 columns in total.
# - he data types of the columns include:
#   - int64 for 26 columns, representing integer values contributing upto 75% of given data set.
#   - object for 9 columns, representing categorical variables or strings contributing upto 25% of given dataset.
# - All columns have non-null values, indicating that there are no missing values in the dataset.

# %% [markdown]
# **.describe()**: method is used to generate descriptive statistics of a DataFrame.
#
# - When you call .describe() on a DataFrame, it provides a summary of various statistical measures for each numeric column in the DataFrame.
#
# - **Count**: The number of non-null (non-missing) values in each column.
#
# - **\*Mean**: The mean (average) value of each column.
#
# - **Std(Standard Deviation)**: The standard deviation, which measures the amount of variation or dispersion of a set of values.
#
# - **Min**: The minimum value in each column.
#
# - **25%(Percentile)**: The 25th percentile (also known as the first quartile). It is the value below which 25% of the data falls.
#
# - **50%(Percentile/Median)**: The median, which represents the middle value of the dataset. It is the value below which 50% of the data falls.
#
# - **75% (Percentile)**: The 75th percentile (also known as the third quartile). It is the value below which 75% of the data falls.
#
# - **Max**: The maximum value in each column.

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# **Findings**
#
# - Age: The average age of employees is approximately 36.92 years, with a standard deviation of approximately 9.14 years. The youngest employee is 18 years old, while the oldest is 60 years old.
# - Rest write it yourself

# %% [markdown]
# # TASK #3: VISUALIZE DATASET

# %% [markdown]
# - **.apply()**: method in Pandas is used to apply a function along an axis of a DataFrame or Series.
# - This method is incredibly versatile and can be used to perform a wide range of operations on the data.

# %%
# Let's replace 'Attritition' , 'overtime' , 'Over18' column with integers before performing any visualizations
data['Attrition'] = data['Attrition'].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
data.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ### Task
#
# **Write a python function that will convert given parameter into desired format**
#
# - Over18(Y,N) -> 1,0
# - OverTime(Yes,No)->1,0

# %%
def convert_column(data_frame, column_name, value_to_convert, target_format):
    data[column_name] = data[column_name].apply(lambda x: target_format if x == value_to_convert else x)
    return data[column_name]

# %%
#Over18

# %%
#OverTime

# %% [markdown]
# **sns.heatmap()**: is a function provided by the Seaborn library in Python for visualizing a heatmap.
#
# - Heatmaps are graphical representations of data where the individual values contained in a matrix are represented as colors.
# - It's a great way to visualize relationships or patterns in data, especially when working with two-dimensional datasets.
# - there are several parameters you can use to customize the appearance and behavior of the heatmap. Here are some of the most commonly used parameters:
#
# **data**: The 2D dataset (e.g., a DataFrame or array) to be plotted as a heatmap.
#
# **cmap**: The colormap to use for coloring the heatmap. Seaborn provides several built-in colormaps, such as 'viridis', 'coolwarm', 'RdBu_r', etc.
#
# **annot**: A boolean value indicating whether to annotate each cell with the numeric value. If set to True, the actual data values will be displayed in each cell.
#
# **fmt**: The format specifier for the annotations. This parameter is used to format the numeric values displayed in each cell. For example, fmt=".2f" will format the values to two decimal places.
#
# **linewidths**: The width of the lines between cells in the heatmap. This parameter controls the spacing between cells.
#
# **linecolor**: The color of the lines between cells.
#
# **square**: A boolean value indicating whether to force the aspect ratio of the heatmap to be square. If set to True, the aspect ratio will be equal.
#
# **cbar**: A boolean value indicating whether to display a colorbar alongside the heatmap. If set to True, a colorbar will be included to indicate the mapping of values to colors.
#
# **cbar_kws**: Additional keyword arguments to customize the appearance of the colorbar, such as the label, ticks, tick labels, etc.
#
# **xticklabels and yticklabels**: A boolean value or a list-like object specifying whether to display the tick labels on the x-axis and y-axis, respectively.
#
# These are just some of the parameters you can use with sns.heatmap(). There are many more parameters available for fine-tuning the appearance and behavior of the heatmap. You can refer: https://seaborn.pydata.org/generated/seaborn.heatmap.html

# %% [markdown]
# **.isnull()**: method in Pandas is used to identify missing or NaN (Not a Number) values in a DataFrame.
#
# - It returns a DataFrame or Series of boolean values, where True indicates the presence of a missing value and False indicates a non-missing value.

# %%
# Let's see if we have any missing data
sns.heatmap(data.isnull(), yticklabels = False, cbar = False, cmap="Blues")
# Out:
# <Axes: >
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# **Findings**
#
# - There is no missing data in given dataset

# %% [markdown]
# ### Plot Histogram of overall dataset
#
# **.hist()**: method in Pandas is used to create a histogram of the values in a DataFrame or Series.
#
# - It allows you to visualize the distribution of numerical data by dividing the data into bins and plotting the frequency or count of values within each bin.
#
# - Here are some of the most commonly used parameters:
#
# - **bins**: int or sequence or str, optional The number of bins to use for the histogram. This can be an integer specifying the number of equal-width bins, a sequence specifying the bin edges, or a string representing the method to calculate the number of bins ('auto', 'fd', 'doane', 'scott', 'stone', 'rice', 'sturges', or 'sqrt'). Default is 'auto'.
#
# - **range**: tuple or None, optional The lower and upper range of the bins. Values outside this range will be ignored. If not provided, range is automatically determined based on the minimum and maximum values in the data.
#
# - **density**: bool, optional If True, the histogram will be normalized such that the area under the histogram equals 1. Default is False.
#
# - **weights**: array-like, optional An array-like object of the same length as the data, containing weights for each data point. Default is None.
#
# - **cumulative**: bool or -1, optional If True, compute a cumulative histogram. If -1, the direction of accumulation is reversed. Default is False.
#
# - **bottom**: array-like, scalar, or None, optional The baseline value from which the histogram is drawn. Default is None.
#
# - **histtype**: {'bar', 'barstacked', 'step', 'stepfilled'}, optional The type of histogram to draw. Default is 'bar'.
#
# - **align**: {'left', 'mid', 'right'}, optional The alignment of the histogram bars along the x-axis. Default is 'mid'.
#
# - **orientation**: {'horizontal', 'vertical'}, optional The orientation of the histogram. Default is 'vertical'.
#
# - **rwidth**: scalar or None, optional The relative width of the bars as a fraction of the bin width. Default is None.
#
# - **log**: bool, optional If True, the histogram axis will be log-scaled. Default is False.
#
# - **color**: str or array-like, optional The color or sequence of colors for the histogram bars. Default is None.
#
# - **label**: str or None, optional The label for the histogram. Default is None.
#
# - **stacked**: bool, optional If True, multiple data sets will be stacked on top of each other. Default is False.
#
# - **grid**: bool, optional If True, a grid will be displayed behind the histogram. Default is False.Here are some of the most commonly used parameters:

# %%
data.hist(bins=30, figsize=(20,20),color='r')
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Attrition'}>,
#         <Axes: title={'center': 'DailyRate'}>,
#         <Axes: title={'center': 'DistanceFromHome'}>,
#         <Axes: title={'center': 'Education'}>],
#        [<Axes: title={'center': 'EmployeeCount'}>,
#         <Axes: title={'center': 'EmployeeNumber'}>,
#         <Axes: title={'center': 'EnvironmentSatisfaction'}>,
#         <Axes: title={'center': 'HourlyRate'}>,
#         <Axes: title={'center': 'JobInvolvement'}>],
#        [<Axes: title={'center': 'JobLevel'}>,
#         <Axes: title={'center': 'JobSatisfaction'}>,
#         <Axes: title={'center': 'MonthlyIncome'}>,
#         <Axes: title={'center': 'MonthlyRate'}>,
#         <Axes: title={'center': 'NumCompaniesWorked'}>],
#        [<Axes: title={'center': 'PercentSalaryHike'}>,
#         <Axes: title={'center': 'PerformanceRating'}>,
#         <Axes: title={'center': 'RelationshipSatisfaction'}>,
# ...

# %% [markdown]
# **Findings**
#
# - Several features such as 'MonthlyIncome' and 'TotalWorkingYears' are tail heavy
# - It makes sense to drop 'EmployeeCount' and 'Standardhours' since they do not change from one employee to the other

# %% [markdown]
# - **df.drop()**: method in Pandas is used to remove rows or columns from a DataFrame.
# - It returns a new DataFrame with the specified rows or columns removed.
# - Drop Row: df.drop('row_label')
# - Drop column: df.drop('column_name', axis=1)
# - you can use the inplace=True parameter to modify the original DataFrame in place rather than creating a new DataFrame

# %%
# drop 'EmployeeCount' and 'Standardhours', Over18, 'employeeNumber' since they do not change from one employee to the other

# %% [markdown]
# **len()**: function in Python is a built-in function that returns the number of items in an object. It can be used with various types of objects, including strings, lists, tuples, dictionaries, sets, and more.

# %%
# Let's see how many employees left the company!
left_df = data[data["Attrition"]==1]
stayed_df = data[data["Attrition"]==0]

# %%
# Count the number of employees who stayed and left also find there percentage

# %% [markdown]
# **Finding**
#
# - It seems taht we are dealing with an imbalanced dataset

# %% [markdown]
# **Comapre left and satyed paremeets by applying describe method**

# %%
left_df.describe()

# %%
stayed_df.describe()

# %% [markdown]
# **Findings**
#
# - Let's compare the mean and std of the employees who stayed and left
# - 'age': mean age of the employees who stayed is higher compared to who left
# - 'DailyRate': Rate of employees who stayed is higher
# - 'DistanceFromHome': Employees who stayed live closer to home
# - 'EnvironmentSatisfaction' & 'JobSatisfaction': Employees who stayed are generally more satisifed with their jobs
# - 'StockOptionLevel': Employees who stayed tend to have higher stock option level

# %% [markdown]
# **Perform Multvariate Analysis by Finding the Correlation**
#
# - **Correlation** is a statistical measure that describes the extent to which two variables change together. In other words, it quantifies the relationship between two variables. Correlation does not imply causation; it simply measures how closely related two variables are.
#
# - There are several types of correlation coefficients that can be calculated, but one of the most common is the Pearson correlation coefficient, also known as Pearson's r. The Pearson correlation coefficient measures the linear relationship between two continuous variables. It ranges from -1 to +1

# %%
correlations = data.corr()
f, ax = plt.subplots(figsize = (20, 20))
sns.heatmap(correlations, annot = True)

# %% [markdown]
# **Findings**
#
# - Job level is strongly correlated with total working hours
# - Monthly income is strongly correlated with Job level
# - Monthly income is strongly correlated with total working hours
# - Age is stongly correlated with monthly income

# %% [markdown]
# **Perform Bivariate Analysis on Age Vs Atriatation and share your findings**
#
# - Bivariate analysis is a statistical method used to examine the relationship between two variables simultaneously. It focuses on understanding how the variation in one variable correlates or affects the variation in another variable.
#
# - In bivariate analysis, the primary goal is to determine whether there exists a relationship, association, or correlation between the two variables. This analysis helps in understanding how changes in one variable may impact the behavior or values of the other variable.
#
# - Bivariate analysis techniques include:
#
# - **Scatter plots**: A visual representation of the relationship between two variables, where each data point corresponds to a paired observation of the two variables.
#
# - **Correlation analysis**: Measures the strength and direction of the linear relationship between two continuous variables using correlation coefficients such as Pearson correlation coefficient.
#
# - **Contingency tables**: Used for categorical variables to display the frequency distribution of observations for each combination of categories in two variables.
#
# - **Cross-tabulation**: A tabular method of summarizing the relationship between two categorical variables by counting the number of observations in each combination of categories.
#
# - **Regression analysis** : Determines the functional relationship between two variables, with one variable treated as the dependent variable and the other as the independent variable.
#
# - Bivariate analysis is valuable in various fields such as economics, social sciences, healthcare, and business, as it provides insights into the dependencies between variables and helps in making informed decisions and predictions.

# %%
plt.figure(figsize=[25, 12])
sns.countplot(x = 'Age', hue = 'Attrition', data = data)
# Out:
# <Axes: xlabel='Age', ylabel='count'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# **Findings**
#
# - Single employees tend to leave compared to married and divorced
# - Sales Representitives tend to leave compared to any other job
# - Less involved employees tend to leave the company
# - Less experienced (low job level) tend to leave the company

# %%
# perform bivariate analysis of JobRole vs Attriation and share findings

# %%
# perform bivariate analysis of Maritial Status vs Attriation

# %%
# perform bivariate analysis of JobInvolvement vs Attriation

# %%
# perform bivariate analyssi of Joblevel vs Attriation

# %%
# Let's see the Gender vs. Monthly Income

# %%
# Let's see the Gender vs. Monthly Income

# %% [markdown]
# # TASK #4: CREATE TESTING AND TRAINING DATASET & PERFORM DATA CLEANING

# %%
# note that we dropped the target 'Atrittion'

# %% [markdown]
# # TASK #5: UNDERSTAND THE INTUITION BEHIND LOGISTIC REGRESSION CLASSIFIERS, ARTIFICIAL NEURAL NETWORKS, AND RANDOM FOREST CLASSIFIER

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=19DpnhFkfsNEDPlH1dkfdr1zO36vRcBit)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1J03xZf6OiYtGV3IgJBUURBWyScpvaAbU)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1WNsznVn7je5r9HGnSLLdABICxrIv2Mrs)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1bX5uGmy5vbYTlp7m4tw_V2kTNzAHpHLp)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1ztrMNehNYWMw6NwhOOC9BDBdnoNirpqZ)

# %% [markdown]
# # TASK #6: UNDERSTAND HOW TO ASSESS CLASSIFICATION MODELS

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1OZLbKm1AJSyvoBgfvlfcLIWZxLOvzOWq)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=11pNdVw4oWeNOWrkadrrxon7FU4qO5m6U)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1Bk1xFW2tGBdwg-njOhw79MxtYBQnK-6x)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=19cXoBqSiqbEGNofnD603bz3xEAsX28hy)

# %% [markdown]
# # TASK #7: TRAIN AND EVALUATE A LOGISTIC REGRESSION CLASSIFIER

# %%
# Testing Set Performance

# %% [markdown]
# # TASK #8: TRAIN AND EVALUATE A RANDOM FOREST CLASSIFIER

# %%
# Testing Set Performance

# %% [markdown]
# # TASK #9: TRAIN AND EVALUATE A DEEP LEARNING MODEL

# %%
# oversampler = SMOTE(random_state=0)
# smote_train, smote_target = oversampler.fit_sample(X_train, y_train)
# epochs_hist = model.fit(smote_train, smote_target, epochs = 100, batch_size = 50)

# %%
# Testing Set Performance

# %% [markdown]
# # EXCELLENT JOB! YOU SHOULD BE PROUD OF YOUR NEWLY ACQUIRED SKILLS
